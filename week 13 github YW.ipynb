# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup
from datetime import datetime, timedelta
import time
import random
import os
import json
from urllib.request import Request, urlopen

# %%
# web crawl from github
driver = webdriver.Chrome(ChromeDriverManager().install())
github_account = {}
# Out:
# ====== WebDriver manager ======
# Current google-chrome version is 96.0.4664
# Get LATEST driver version for 96.0.4664
# Driver [C:\Users\17163\.wdm\drivers\chromedriver\win32\96.0.4664.45\chromedriver.exe] found in cache

# %%
def get_git(url):
    driver.get(url)
    github_account["login"] = driver.find_element_by_xpath('//meta[@property="profile:username"]').get_attribute('content')
    github_account["id"] = driver.find_element_by_class_name('js-site-search-form').get_attribute('data-scope-id')
    github_account["html_url"] = driver.find_element_by_xpath('//meta[@property="og:url"]').get_attribute('content')
    github_account["type"] = driver.find_element_by_class_name('js-site-search-form').get_attribute('data-scope-type') 
#     github_account["location"] = driver.find_element_by_xpath('//span[@itemprop="location"]').get_attribute('title')
    return github_account

# %%
# web crawl from monster
head = "https://www.monster.com/"
chromedriver = "/Applications/chromedriver"
os.environ["webdriver.chrome.driver"] = chromedriver

# job_titles = ["data+scientist"]
job_titles = ["data+scientist"]

# %%
def get_soup(url):
    """
    This function get the beautifulsoup object of a webpage.

    Args:
        url (str): the link string of webpage

    Returns:
        soup (obj): beautifulsoup object
    """
    request = Request(url, headers={'User-Agent': 'Resistance is futile'})
    response = urlopen(request)
    return BeautifulSoup(response, "html.parser")

def get_jobs_of_title(job_title):
    """
    Args:
        job_title (str): example: 'data+scientist'

    Returns:
    """

    #needed to be changed
    num_pages = 1 #number of pages to scrape
    page_gap_min = 3 #min sleep time between pages
    page_gap_max = 5 #max sleep time between pages
    job_per_page = 50 #number of jobs in one page
    job_gap_min = 5 #min sleep time between jobs
    job_gap_max = 6 #max sleep time between jobs

    for i in range(num_pages): 
        #sleep between each call
        gap = random.uniform(page_gap_min,page_gap_max) 
        time.sleep(gap)

        #each page contains 50 jobs
        tail = "jobs?q={0}&sort=date&limit={1}".format(job_title,job_per_page)
        if i>0:
            tail += "&start={0}".format(i*job_per_page)

        #get link to joblist page
        url = head+tail 
         
        #get links to webpages of jobs on the joblist
        job_page_links = get_job_links_from_page(url)

        for job_page_link in job_page_links:
            gap = random.uniform(job_gap_min,job_gap_max) 
            time.sleep(gap)
            data = get_info_from_job_page(job_page_link)

            print(json.dumps(data))

def get_job_links_from_page(url):
    """
    This function gets the links of the jobs on the joblist page.

    Args:
        url (str): link to joblist page

    Returns:
        job_page_links (list): list of links to the webpages of the jobs
    """

    job_page_links = []
    soup = get_soup(url)
    for item in soup.find_all("a", href=True):
        if '/rc/clk?jk=' in str(item) and 'fccid=' in str(item):
            link = item['href'].split("clk?")[1]
            job_page_links.append(head+'viewjob?'+link)
    return job_page_links

def get_info_from_job_page(url):
    """
    This function get all the useful info from the job webpage.

    Args:
        url (str): link to job webpage

    Returns:
        data (dict): dictionary with keywords: 
                     time_stamp, original_link, job_title, location, company, description
    """
    soup = get_soup(url)
    data = {}
    time_str = soup.find('div',class_='result-link-bar').find('span').getText()
    try:
        data["time_stamp"] = get_timestamp(time_str).strftime("%d-%m-%Y %H:%M")
        data["job_title"] = soup.find('b', class_='jobtitle').getText()
        data["location"] = soup.find('span', class_='location').getText()
        data["company"] = soup.find('span', class_='company').getText()
        data["description"] = soup.find('td',class_='snip').find('div').getText()

        re_link = soup.find('a',class_='sl ws_label')['href'].split("&from=")[0]
        re_link = head[:-1]+re_link
        data["original_link"] = get_original_link(re_link)
    except:
        pass
    return data

def get_timestamp(time_str):
    """
    Calculate the timestamp from the time string.
    
    Args:
        time_str (str): time string, like '2 hours ago'

    Returns:
        time_stamp (obj): timestamp object
    """
    if 'hour' in time_str:
        lag = int(time_str.split('hour')[0])
        delta = timedelta(hours=lag)
        now = datetime.utcnow().replace(second=0,minute=0)
        return now-delta
    else:
        return -1

def get_original_link(url):
    """
    Get the original link of the job description.
    
    Args:
        url (str): the link in Indeed database

    Returns:
        url (str): the original link to the job description
    """
    driver = webdriver.Chrome(chromedriver)
    driver.get(url)
    time.sleep(2)
    original_url = driver.current_url
    driver.quit()
    return original_url

# %%
get_soup("https://www.monster.com/")
# Out:
# <!DOCTYPE html>
# <html lang="en-us"><head><meta charset="utf-8"/><meta content="ie=edge" http-equiv="x-ua-compatible"/><meta content="width=device-width, initial-scale=1, shrink-to-fit=no" name="viewport"/><meta content="Gatsby 2.32.13" name="generator"/><title data-react-helmet="true">Monster Jobs - Job Search, Career Advice &amp; Hiring Resources | Monster.com</title><link as="font" crossorigin="anonymous" data-react-helmet="true" href="/static/Proxima-Nova-Regular-2000f9d8a8df2554f0c0994f44057524.woff2" rel="preload" type="font/woff"/><link as="font" crossorigin="anonymous" data-react-helmet="true" href="/static/Proxima-Nova-SemiBold-2b6fce92d9bb4f455f961b9c9df136b9.woff2" rel="preload" type="font/woff2"/><link as="font" crossorigin="anonymous" data-react-helmet="true" href="/static/Proxima-Nova-Bold-d31288e9360bd8c887f67632bd998983.woff2" rel="preload" type="font/woff2"/><link data-react-helmet="true" href="https://www.monster.com" rel="canonical"/><link data-react-helmet="true" href="/favicon.ico" rel="shortcut icon"/><link data-react-helmet="true" href="/HeadIcons/m-touch-icon-57.png" rel="apple-touch-icon-precomposed" sizes="57x57"/><link data-react-helmet="true" href="/HeadIcons/m-touch-icon-72.png" rel="apple-touch-icon-precomposed" sizes="72x72"/><link data-react-helmet="true" href="/HeadIcons/m-touch-icon-114.png" rel="apple-touch-icon-precomposed" sizes="114x114"/><link data-react-helmet="true" href="/HeadIcons/m-touch-icon-144.png" rel="apple-touch-icon-precomposed" sizes="144x144"/><meta content="IE=edge,chrome=1" data-react-helmet="true" http-equiv="X-UA-Compatible"/><meta content="text/html; charset=utf-8" data-react-helmet="true" http-equiv="Content-Type"/><meta content="no-cache" data-react-helmet="true" http-equiv="cache-control"/><meta content="0" data-react-helmet="true" http-equiv="Expires"/><meta content="width=device-width, initial-scale=1.0, maximum-scale=5.0, minimum-scale=1.0" data-react-helmet="true" name="viewport"/><meta content="F8DBA23FC2A85B0C89741819C478E36" data-react-helmet="true" name="msvalidate.01"/><meta content="hdRwRevikG3Zl1Ju07n-CT4cHgNgEBwY1J0h6mFcmv4" data-react-helmet="true" name="google-site-verification"/><meta content="Monster is your source for jobs and career opportunities. Search for jobs, read career advice from Monster's job experts, and find hiring and recruiting advice." data-react-helmet="true" name="description"/><meta content="website" data-react-helmet="true" property="og:type"/><meta content="Monster Jobs - Job Search, Career Advice &amp; Hiring Resources | Monster.com" data-react-helmet="true" property="og:title"/><meta content="Monster is your source for jobs and career opportunities. Search for jobs, read career advice from Monster's job experts, and find hiring and recruiting advice." data-react-helmet="true" property="og:description"/><meta content="http://securemedia.newjobs.com/dege/b2c/www20/Images/Social-Images/Monster-Facebook-1.jpg" data-react-helmet="true" property="og:image"/><meta content="https://www.monster.com" data-react-helmet="true" property="og:url"/><meta content="87877000648" data-react-helmet="true" property="fb:pages"/><meta content="https://www.monster.com" data-react-helmet="true" name="twitter:url"/><meta content="Monster is your source for jobs and career opportunities. Search for jobs, read career advice from Monster's job experts, and find hiring and recruiting advice." data-react-helmet="true" name="twitter:card"/><script data-react-helmet="true" type="application/ld+json">{
#   "@context": "http://schema.org",
#   "@type": "Organization",
#   "legalName": "Monster",
#   "alternateName": "Monster.com",
#   "description": "Monster is your source for jobs and career opportunities. At Monster, we're dedicated to making the job search process simple—and stress free. Our job search engine is built with powerful technology that aims to match the right job opportunities with the right people. To find the latest and most relevant job openings, simply browse by job title, company, city or state. Or become a member to get the first alerts on jobs you'll like. Also, make sure to check out the Career Advice section of the site for other job search tools like resume samples and interview tips. So, start searching, and see what we've got. You might just find better.",
#   "url": "https://www.monster.com/",
#   "logo": "https://securemedia.newjobs.com/global/img/jobr/monster-app-logo.png",
#   "sameAs": [
#     "https://www.facebook.com/monster",
#     "https://twitter.com/Monster",
#     "https://www.instagram.com/monster/",
#     "https://www.pinterest.com/monsterdotcom/",
#     "https://www.youtube.com/monster",
#     "https://www.linkedin.com/company/monster/"
#   ]
# }</script><script data-react-helmet="true" type="application/ld+json">{
#   "@context": "http://schema.org",
#   "@type": "WebSite",
#   "name": "Monster",
#   "url": "https://www.monster.com",
#   "potentialAction": {
#     "@type": "SearchAction",
#     "target": "https://www.monster.com/jobs/search/?q={search_term_string}&from=GoogleSearchAction",
#     "query-input": "required name=search_term_string"
#   }
# }</script><script data-react-helmet="true" type="application/ld+json">{
#   "@context": "http://schema.org/",
#   "@type": "BreadcrumbList",
#   "itemListElement": [
#     {
#       "@type": "ListItem",
#       "position": "1",
#       "item": {
#         "@id": "https://www.monster.com/jobs/",
#         "name": "For Job Seekers"
#       }
#     },
#     {
#       "@type": "ListItem",
#       "position": "2",
#       "item": {
#         "@id": "https://hiring.monster.com/",
#         "name": "For Employers"
#       }
#     },
#     {
#       "@type": "ListItem",
#       "position": "3",
#       "item": {
#         "@id": "https://www.monster.com/career-advice/",
#         "name": "Career Advice for Job Seekers"
#       }
#     },
#     {
#       "@type": "ListItem",
#       "position": "4",
#       "item": {
#         "@id": "https://hiring.monster.com/employer-resources/",
#         "name": "Hiring Resources for Employers"
#       }
#     }
#   ]
# }</script><style id="jss-server-side">.MuiSvgIcon-root{fill:currentColor;width:1em;height:1em;display:inline-block;font-size:1.5rem;transition:fill .2s cubic-bezier(.4,0,.2,1) 0s;flex-shrink:0;-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none}.MuiSvgIcon-colorPrimary{color:#3f51b5}.MuiSvgIcon-colorSecondary{color:#f50057}.MuiSvgIcon-colorAction{color:rgba(0,0,0,.54)}.MuiSvgIcon-colorError{color:#f44336}.MuiSvgIcon-colorDisabled{color:rgba(0,0,0,.26)}.MuiSvgIcon-fontSizeInherit{font-size:inherit}.MuiSvgIcon-fontSizeSmall{font-size:1.25rem}.MuiSvgIcon-fontSizeLarge{font-size:2.1875rem}.MuiContainer-root{width:100%;display:block;box-sizing:border-box;margin-left:auto;margin-right:auto;padding-left:4px;padding-right:4px}@media (min-width:375px){.MuiContainer-root{padding-left:8px;padding-right:8px}}.MuiContainer-disableGutters{padding-left:0;padding-right:0}@media (min-width:375px){.MuiContainer-fixed{max-width:375px}}@media (min-width:768px){.MuiContainer-fixed{max-width:768px}}@media (min-width:1024px){.MuiContainer-fixed{max-width:1024px}}@media (min-width:1440px){.MuiContainer-fixed{max-width:1440px}}@media (min-width:0px){.MuiContainer-maxWidthXs{max-width:444px}}@media (min-width:375px){.MuiContainer-maxWidthSm{max-width:375px}}@media (min-width:768px){.MuiContainer-maxWidthMd{max-width:768px}}@media (min-width:1024px){.MuiContainer-maxWidthLg{max-width:1024px}}@media (min-width:1440px){.MuiContainer-maxWidthXl{max-width:1440px}}.MuiBadge-root{display:inline-flex;position:relative;flex-shrink:0;vertical-align:middle}.MuiBadge-badge{height:20px;display:flex;padding:0 6px;z-index:1;position:absolute;flex-wrap:wrap;font-size:.75rem;min-width:20px;box-sizing:border-box;transition:transform 225ms cubic-bezier(.4,0,.2,1) 0s;align-items:center;font-family:Roboto,Helvetica,Arial,sans-serif;font-weight:500;line-height:1;align-content:center;border-radius:10px;flex-direction:row;justify-content:center}.MuiBadge-colorPrimary{color:#fff;background-color:#3f51b5}.MuiBadge-colorSecondary{color:#fff;background-color:#f50057}.MuiBadge-colorError{color:#fff;background-color:#f44336}.MuiBadge-dot{height:8px;padding:0;min-width:8px;border-radius:4px}.MuiBadge-anchorOriginTopRightRectangle{top:0;right:0;transform:scale(1) translate(50%,-50%);transform-origin:100% 0}.MuiBadge-anchorOriginTopRightRectangle.MuiBadge-invisible{transform:scale(0) translate(50%,-50%)}.MuiBadge-anchorOriginTopRightRectangular{top:0;right:0;transform:scale(1) translate(50%,-50%);transform-origin:100% 0}.MuiBadge-anchorOriginTopRightRectangular.MuiBadge-invisible{transform:scale(0) translate(50%,-50%)}.MuiBadge-anchorOriginBottomRightRectangle{right:0;bottom:0;transform:scale(1) translate(50%,50%);transform-origin:100% 100%}.MuiBadge-anchorOriginBottomRightRectangle.MuiBadge-invisible{transform:scale(0) translate(50%,50%)}.MuiBadge-anchorOriginBottomRightRectangular{right:0;bottom:0;transform:scale(1) translate(50%,50%);transform-origin:100% 100%}.MuiBadge-anchorOriginBottomRightRectangular.MuiBadge-invisible{transform:scale(0) translate(50%,50%)}.MuiBadge-anchorOriginTopLeftRectangle{top:0;left:0;transform:scale(1) translate(-50%,-50%);transform-origin:0 0}.MuiBadge-anchorOriginTopLeftRectangle.MuiBadge-invisible{transform:scale(0) translate(-50%,-50%)}.MuiBadge-anchorOriginTopLeftRectangular{top:0;left:0;transform:scale(1) translate(-50%,-50%);transform-origin:0 0}.MuiBadge-anchorOriginTopLeftRectangular.MuiBadge-invisible{transform:scale(0) translate(-50%,-50%)}.MuiBadge-anchorOriginBottomLeftRectangle{left:0;bottom:0;transform:scale(1) translate(-50%,50%);transform-origin:0 100%}.MuiBadge-anchorOriginBottomLeftRectangle.MuiBadge-invisible{transform:scale(0) translate(-50%,50%)}.MuiBadge-anchorOriginBottomLeftRectangular{left:0;bottom:0;transform:scale(1) translate(-50%,50%);transform-origin:0 100%}.MuiBadge-anchorOriginBottomLeftRectangular.MuiBadge-invisible{transform:scale(0) translate(-50%,50%)}.MuiBadge-anchorOriginTopRightCirc ...
# .dFAQNP,.dFAQNP:visited{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;padding:7px 16px;border:2px solid #6e46ae;border-radius:4px;background-color:transparent;font-family:Proxima Nova,Helvetica,Arial,sans-serif;font-weight:600;font-size:14px;color:#6e46ae;line-height:18px;text-transform:none;}/*!sc*/
# .dFAQNP:focus{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;padding:7px 16px;border:2px solid #57378a;border-radius:4px;background-color:#57378a;font-family:Proxima Nova,Helvetica,Arial,sans-serif;font-weight:600;font-size:14px;color:#ffffff;line-height:18px;text-transform:none;}/*!sc*/
# .dFAQNP:hover{cursor:pointer;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;padding:7px 16px;border:2px solid #6e46ae;border-radius:4px;background-color:#6e46ae;font-family:Proxima Nova,Helvetica,Arial,sans-serif;font-weight:600;font-size:14px;color:#ffffff;line-height:18px;text-transform:none;}/*!sc*/
# data-styled.g5[id="sc-eCImPb"]{content:"dFAQNP,"}/*!sc*/
# .eUTVaK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# data-styled.g35[id="sc-bYoBSM"]{content:"eUTVaK,"}/*!sc*/
# .iuqLXt{width:32px;margin-bottom:24px;}/*!sc*/
# data-styled.g36[id="sc-kLwhqv"]{content:"iuqLXt,"}/*!sc*/
# .kskqbe{border-radius:50%;-webkit-transition:width 0.2s,height 0.2s;transition:width 0.2s,height 0.2s;-webkit-animation:1s kvdmkM linear infinite;animation:1s kvdmkM linear infinite;width:12px;height:12px;background-color:#e9e7f7;}/*!sc*/
# data-styled.g37[id="sc-ikJyIC"]{content:"kskqbe,"}/*!sc*/
# .gXrHpT{-webkit-animation-delay:calc(1s / 3);animation-delay:calc(1s / 3);}/*!sc*/
# data-styled.g38[id="sc-jJoQJp"]{content:"gXrHpT,"}/*!sc*/
# .hHrFfF{-webkit-animation-delay:calc(1s / (4 / 3));animation-delay:calc(1s / (4 / 3));}/*!sc*/
# data-styled.g39[id="sc-hiCibw"]{content:"hHrFfF,"}/*!sc*/
# html,body,body div,span,object,iframe,h1,h2,h3,h4,h5,h6,p,blockquote,pre,abbr,address,cite,code,del,dfn,em,img,ins,kbd,q,samp,small,strong,sub,sup,var,b,i,dl,dt,dd,ol,ul,li,fieldset,form,label,legend,table,caption,tbody,tfoot,thead,tr,th,td,article,aside,figure,footer,header,hgroup,menu,nav,section,time,mark,audio,video{margin:0;padding:0;border:0;outline:0;font-size:100%;vertical-align:baseline;background:transparent;}/*!sc*/
# p.paragraph-sm{font-family:Proxima Nova;font-weight:400;font-size:14px;color:#212121;line-height:21px;}/*!sc*/
# p,p.paragraph-md{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#212121;line-height:24px;}/*!sc*/
# p.paragraph-lg{font-family:Proxima Nova;font-weight:400;font-size:18px;color:#212121;line-height:27px;}/*!sc*/
# a{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#6e46ae;line-height:24px;}/*!sc*/
# a.link-sm{font-family:Proxima Nova;font-weight:400;font-size:14px;color:#6e46ae;line-height:18px;}/*!sc*/
# a.link-md{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#6e46ae;line-height:24px;}/*!sc*/
# a.link-lg{font-family:Proxima Nova;font-weight:400;font-size:18px;color:#6e46ae;line-height:27px;}/*!sc*/
# a:visited{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#6e46ae;line-height:24px;}/*!sc*/
# a:active{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#6e46ae;line-height:24px;}/*!sc*/
# ul li{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#212121;line-height:24px;}/*!sc*/
# ol li{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#212121;line-height:24px;}/*!sc*/
# h1,.h1{font-family:Proxima Nova;font-weight:700;font-size:40px;color:#212121;line-height:50px;}/*!sc*/
# h2,.h2{font-family:Proxima Nova;font-weight:700;font-size:32px;color:#212121;line-height:40px;}/*!sc*/
# h3,.h3{font-family:Proxima Nova;font-weight:700;font-size:25px;color:#212121;line-height:31px;}/*!sc*/
# h4,.h4{font-family:Proxima Nova;font-weight:700;font-size:21px;color:#212121;line-height:26px;}/*!sc*/
# h5,.h5{font-family:Proxima Nova;font-weight:700;font-size:18px;color:#212121;line-height:23px;}/*!sc*/
# h6,.h6{font-family:Proxima Nova;font-weight:700;font-size:16px;color:#212121;line-height:20px;}/*!sc*/
# data-styled.g99[id="sc-global-cgorUy1"]{content:"sc-global-cgorUy1,"}/*!sc*/
# .hEWBGm{display:block;}/*!sc*/
# @media screen and (min-width:768px){.hEWBGm{display:none;}}/*!sc*/
# data-styled.g157[id="sc-hkgtus"]{content:"hEWBGm,"}/*!sc*/
# .dnxMQg{display:none;}/*!sc*/
# @media screen and (min-width:768px){.dnxMQg{display:block;}}/*!sc*/
# data-styled.g158[id="sc-bSqaIl"]{content:"dnxMQg,"}/*!sc*/
# .QOCLR{width:100%;-webkit-transition:background-color .2s ease-in-out;transition:background-color .2s ease-in-out;position:relative;z-index:100;background-color:#ffffff;}/*!sc*/
# data-styled.g159[id="sc-jvvksu"]{content:"QOCLR,"}/*!sc*/
# .iozbWu{font-family:Proxima Nova;font-weight:400;font-size:16px;color:#212121;line-height:24px;position:relative;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex-flow:wrap;-ms-flex-flow:wrap;flex-flow:wrap;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-shadow:0 0 4px 0 rgba(189,189,189,0.1);-webkit-transition:.2s ease-in-out;transition:.2s ease-in-out;-webkit-transition-property:background-color;transition-property:background-color;background-color:#ffffff;}/*!sc*/
# @media screen and (min-width:768px){.iozbWu{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;background-color:#ffffff;}}/*!sc*/
# @media screen and (min-width:calc(1440px + 24px)){.iozbWu{-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}}/*!sc*/
# data-styled.g160[id="sc-edERGn"]{content:"iozbWu,"}/*!sc*/
# .gXtbrX{box-sizing:border-box;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:100%;min-height:80px;padding:0px 24px;}/*!sc*/
# @media screen and (max-width:768px){.gXtbrX{min-height:72px;}}/*!sc*/
# @media screen and (min-width:768px){.gXtbrX{-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;margin:0 auto;}}/*!sc*/
# @media screen and (min-width:1024px){.gXtbrX{padding:0 32px;}}/*!sc*/
# @media screen and (min-width:1440px){.gXtbrX{padding:0 40px;}}/*!sc*/
# @media screen and (min-width:calc(1440px + 24px)){.gXtbrX{max-width:1520px;}}/*!sc*/
# data-styled.g161[id="sc-jlsrNB"]{content:"gXtbrX,"}/*!sc*/
# .kOTfSo{z-index:3;}/*!sc*/
# .kOTfSo a,.kOTfSo svg{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# data-styled.g162[id="sc-iWBNLc"]{content:"kOTfSo,"}/*!sc*/
# .hqcOzp,.hqcOzp.hqcOzp{width:144px;height:100%;max-height:24px;}/*!sc*/
# data-styled.g163[id="sc-hYQoXb"]{content:"hqcOzp,"}/*!sc*/
# .fbeWUH,.fbeWUH.fbeWUH{width:40px;height:100%;}/*!sc*/
# data-styled.g164[id="sc-hJZKUC"]{content:"fbeWUH,"}/*!sc*/
# .kbXrNq{position:absolute;top:0;right:0;bottom:0;left:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-basis:auto;-ms-flex-preferred-size:auto;flex-basis:auto;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# @media screen and (min-width:768px){.kbXrNq{box-sizing:border-box;position:relative;background-color:#f2f2f2;top:auto;-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex:1;-ms-flex:1;flex:1;width:100%;padding:0 24px;}}/*!sc*/
# @media screen and (min-width:1024px){.kbXrNq{padding:0 32px;}}/*!sc*/
# @media screen and (min-width:1440px){.kbXrNq{padding:0 40px;}}/*!sc*/
# data-styled.g169[id="sc-kHxTfl"]{content:"kbXrNq,"}/*!sc*/
# .fkWbKr{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .fkWbKr a:hover,.fkWbKr a:focus,.fkWbKr a:active{color:#ffffff;}/*!sc*/
# data-styled.g170[id="sc-ksHpcM"]{content:"fkWbKr,"}/*!sc*/
# .knvEvz{background-color:transparent;}/*!sc*/
# .knvEvz,.knvEvz:hover,.knvEvz:focus,.knvEvz:active,.knvEvz:visited{margin:0;padding:8px 20px 7px;text-transform:uppercase;-webkit-text-decoration:none;text-decoration:none;font-family:Proxima Nova SemiBold,Helvetica,sans-serif;font-weight:normal;font-size:12px;line-height:18px;border-width:1px;}/*!sc*/
# data-styled.g171[id="sc-gXRojI"]{content:"knvEvz,"}/*!sc*/
# .ivlKqd{outline:none;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;position:absolute;margin-top:-9px;top:50%;right:0;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);width:20px;height:20px;cursor:pointer;background-color:transparent;padding:0;box-sizing:content-box;border:6px solid transparent;}/*!sc*/
# data-styled.g172[id="sc-bGaVxB"]{content:"ivlKqd,"}/*!sc*/
# .iMiare{display:block;top:2px;margin-top:-2px;}/*!sc*/
# .iMiare,.iMiare::before,.iMiare::after{position:absolute;width:20px;height:3px;background-color:#3d2462;border-radius:3px;-webkit-transition:.2s ease-in-out;transition:.2s ease-in-out;-webkit-transition-property:-webkit-transform,background-color,opacity;-webkit-transition-property:transform,background-color,opacity;transition-property:transform,background-color,opacity;}/*!sc*/
# .iMiare::before,.iMiare::after{content:'';display:block;}/*!sc*/
# .iMiare::before{top:7px;-webkit-transition-property:-webkit-transform,opacity;-webkit-transition-property:transform,opacity;transition-property:transform,opacity;-webkit-transition-timing-function:ease;transition-timing-function:ease;-webkit-transition-duration:.2s;transition-duration:.2s;}/*!sc*/
# .iMiare::after{top:14px;}/*!sc*/
# data-styled.g173[id="sc-fydGpi"]{content:"iMiare,"}/*!sc*/
# .jlFVjm{position:relative;z-index:2;}/*!sc*/
# data-styled.g174[id="sc-gnnDb"]{content:"jlFVjm,"}/*!sc*/
# .lhfTMq{position:relative;width:32px;z-index:3;}/*!sc*/
# data-styled.g175[id="sc-cjrPHo"]{content:"lhfTMq,"}/*!sc*/
# .FXfhh .MuiBadge-badge{background-color:#d80000;}/*!sc*/
# data-styled.g176[id="sc-igXgud"]{content:"FXfhh,"}/*!sc*/
# .lamlMS{margin:0 8px;}/*!sc*/
# .lamlMS,.lamlMS:visited{color:#d5d3e4;}/*!sc*/
# .lamlMS:hover,.lamlMS:focus,.lamlMS:active{color:#00788c;}/*!sc*/
# .lamlMS svg{display:block;height:24px;}/*!sc*/
# .lamlMS:first-child{margin-left:0;}/*!sc*/
# .lamlMS:last-child{margin-right:0;}/*!sc*/
# @media screen and (min-width:768px){.lamlMS,.lamlMS:visited{color:#212121;}.lamlMS:hover,.lamlMS:focus,.lamlMS:active{color:#00788c;}}/*!sc*/
# data-styled.g177[id="sc-JEhMO"]{content:"lamlMS,"}/*!sc*/
# .ckCBlB{box-sizing:border-box;position:relative;z-index:2;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}/*!sc*/
# @media screen and (min-width:768px){.ckCBlB{-webkit-box-pack:end;-webkit-justify-content:flex-end;-ms-flex-pack:end;justify-content:flex-end;padding:0;margin:24px 0 24px;}}/*!sc*/
# @media screen and (min-width:calc(1440px + 8px)){.ckCBlB{margin:24px 0;}}/*!sc*/
# data-styled.g179[id="sc-itWPBs"]{content:"ckCBlB,"}/*!sc*/
# .bYBkMg{position:relative;z-index:4;min-width:32px;}/*!sc*/
# @media screen and (min-width:768px){.bYBkMg{min-width:inherit;}}/*!sc*/
# data-styled.g180[id="sc-dcgwPl"]{content:"bYBkMg,"}/*!sc*/
# .hXhzHY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;width:100%;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;height:100vh;margin-top:72px;-webkit-transition:.3s ease-in-out;transition:.3s ease-in-out;-webkit-transition-property:max-height,clip-path;transition-property:max-height,clip-path;-webkit-clip-path:inset(0);clip-path:inset(0);max-height:0;}/*!sc*/
# @media screen and (min-width:768px){.hXhzHY{overflow:auto;height:auto;max-height:none;background-color:inherit;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;max-width:1440px;margin:0 auto;}}/*!sc*/
# data-styled.g188[id="sc-lhMiDA"]{content:"hXhzHY,"}/*!sc*/
# .hTrxPC{list-style-type:none;padding:0;margin:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100vw;height:100vh;-webkit-transition:max-height .3s ease-in-out;transition:max-height .3s ease-in-out;background-color:#402965;overflow:hidden;max-height:0;}/*!sc*/
# @media screen and (min-width:768px){.hTrxPC{width:100%;background-color:inherit;width:auto;height:auto;max-height:100%;text-align:center;-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;}}/*!sc*/
# data-styled.g189[id="sc-cvlWTT"]{content:"hTrxPC,"}/*!sc*/
# .hwgDXS{border-bottom:1px solid #57378a;background-color:inherit;}/*!sc*/
# .hwgDXS,.hwgDXS a,.hwgDXS a:visited{color:#ffffff;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hwgDXS a{display:block;padding:16px 24px 16px 24px;}/*!sc*/
# .hwgDXS:hover,.hwgDXS:focus,.hwgDXS:active,.hwgDXS:hover a,.hwgDXS:focus a,.hwgDXS:active a{background-color:#57378a;}/*!sc*/
# @media screen and (min-width:768px){.hwgDXS{margin:0 24px;padding-bottom:0;}.hwgDXS,.hwgDXS a,.hwgDXS a:visited{color:#212121;font-weight:inherit;-webkit-text-decoration:none;text-decoration:none;border-top:2px solid transparent;border-bottom:2px solid transparent;-webkit-transition:.3s ease-in-out;transition:.3s ease-in-out;-webkit-transition-property:color,border-bottom;transition-property:color,border-bottom;}.hwgDXS a{padding:12px 0;}.hwgDXS:hover,.hwgDXS:focus,.hwgDXS:active{padding-bottom:0;border-bottom:2px solid #3d2462;}.hwgDXS:hover,.hwgDXS:focus,.hwgDXS:active,.hwgDXS:hover a,.hwgDXS:focus a,.hwgDXS:active a{color:#3d2462;background-color:inherit;-webkit-text-decoration:none;text-decoration:none;}.hwgDXS:first-of-type{margin-left:48px - 2px;}}/*!sc*/
# @media screen and (min-width:992px){.hwgDXS{margin:0 32px;}.hwgDXS:first-of-type{margin-left:48px;}}/*!sc*/
# @media screen and (min-width:768px){.hwgDXS:first-of-type{margin-left:0;}}/*!sc*/
# data-styled.g190[id="sc-fTQvRK"]{content:"hwgDXS,"}/*!sc*/
# .hIbwqr{margin:12px 0 0 8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;}/*!sc*/
# data-styled.g214[id="sc-fkJVfC"]{content:"hIbwqr,"}/*!sc*/
# .fQTYrb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;box-sizing:border-box;padding:24px;background-color:#ffffff;height:250px;}/*!sc*/
# @media screen and (min-width:768px){}/*!sc*/
# @media screen and (min-width:1024px){}/*!sc*/
# @media screen and (min-width:1440px){}/*!sc*/
# data-styled.g215[id="sc-iuqRDJ"]{content:"fQTYrb,"}/*!sc*/
# .kyfJLc{background-color:#ffffff;border:0;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-wrap:wrap;-ms-flex-wrap:wrap;flex-wrap:wrap;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:24px;}/*!sc*/
# data-styled.g216[id="sc-eBTqsU"]{content:"kyfJLc,"}/*!sc*/
# html{box-sizing:border-box;}/*!sc*/
# *,*:before,*:after{box-sizing:inherit;}/*!sc*/
# html,body,a,p,h1,h2,h3,h4,h5,h6{font-family:'Proxima Nova',Helvetica,Arial,Sans-Serif;}/*!sc*/
# #onetrust-banner-sdk{font-family:'Proxima Nova',Helvetica,Arial,Sans-Serif;}/*!sc*/
# data-styled.g287[id="sc-global-fjmmSe1"]{content:"sc-global-fjmmSe1,"}/*!sc*/
# .ehpwqe{display:block;width:100%;}/*!sc*/
# @media screen and (min-width:768px){.ehpwqe{display:none;}}/*!sc*/
# data-styled.g292[id="search-sectionstyle__IsMobileOnly-sc-1q9muf3-0"]{content:"ehpwqe,"}/*!sc*/
# .hBuWfs{display:none;}/*!sc*/
# @media screen and (min-width:768px){.hBuWfs{display:block;width:100%;}}/*!sc*/
# data-styled.g293[id="search-sectionstyle__IsTabletAndDesktopOnly-sc-1q9muf3-1"]{content:"hBuWfs,"}/*!sc*/
# .fLdvvy{background-color:#230939;}/*!sc*/
# data-styled.g294[id="search-sectionstyle__SearchSectionWrapOuter-sc-1q9muf3-2"]{content:"fLdvvy,"}/*!sc*/
# .ckjlFC{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:0 24px;min-height:384px;}/*!sc*/
# @media screen and (min-width:768px){.ckjlFC{padding:0 24px;min-height:560px;}}/*!sc*/
# @media screen and (min-width:1024px){.ckjlFC{padding:0 64px;}}/*!sc*/
# @media screen and (min-width:1440px){.ckjlFC{padding:0 120px;min-height:570px;}}/*!sc*/
# data-styled.g295[id="search-sectionstyle__SearchSectionWrapInner-sc-1q9muf3-3"]{content:"ckjlFC,"}/*!sc*/
# .brqYxw{font-family:Proxima Nova;font-weight:700;font-size:32px;color:#212121;line-height:40px;font-family:'Proxima Nova Bold','Proxima Nova';color:#c1baeb;margin-bottom:24px;text-align:center;}/*!sc*/
# .brqYxw > span{color:white;}/*!sc*/
# data-styled.g296[id="search-sectionstyle__SearchSectionTitle-sc-1q9muf3-4"]{content:"brqYxw,"}/*!sc*/
# .ibHzMc{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;padding:80px 0;}/*!sc*/
# data-styled.g297[id="search-sectionstyle__SearchSectionMobileWrap-sc-1q9muf3-5"]{content:"ibHzMc,"}/*!sc*/
# .fhlivs{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;width:100%;border-radius:76px;max-width:366px;padding:16px 24px;background-color:#ffffff;border:0;cursor:pointer;}/*!sc*/
# data-styled.g298[id="search-sectionstyle__SearchSectionButton-sc-1q9muf3-6"]{content:"fhlivs,"}/*!sc*/
# .delkuD{color:#b051aa;}/*!sc*/
# .delkuD.search{font-size:24px;}/*!sc*/
# data-styled.g299[id="search-sectionstyle__SearchSectionButtonIcon-sc-1q9muf3-7"]{content:"delkuD,"}/*!sc*/
# .bXRGh{font-family:Proxima Nova;font-weight:400;font-size:18px;color:#212121;line-height:27px;font-family:'Proxima Nova SemiBold','Proxima Nova';color:#3d2462;width:100%;text-align:center;line-height:1.25;}/*!sc*/
# data-styled.g300[id="search-sectionstyle__SearchSectionButtonText-sc-1q9muf3-8"]{content:"bXRGh,"}/*!sc*/
# .iqFPdu{width:100%;background-color:#3d2462;min-height:436px;}/*!sc*/
# @media screen and (min-width:768px){.iqFPdu{min-height:452px;}}/*!sc*/
# @media screen and (min-width:1024px){.iqFPdu{min-height:446px;}}/*!sc*/
# @media screen and (min-width:1440px){.iqFPdu{min-height:556px;}}/*!sc*/
# data-styled.g304[id="hero-cardstyle__HeaderCardOuter-sc-8gb5fx-0"]{content:"iqFPdu,"}/*!sc*/
# .GiGZF{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:space-around;-webkit-justify-content:space-around;-ms-flex-pack:space-around;justify-content:space-around;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;max-width:1440px;box-sizing:border-box;margin:0 auto;padding:24px 24px 40px;}/*!sc*/
# @media screen and (min-width:768px){.GiGZF{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:32px 24px;}}/*!sc*/
# @media screen and (min-width:1024px){.GiGZF{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:56px 24px;}}/*!sc*/
# @media screen and (min-width:1440px){.GiGZF{-webkit-flex-direction:row;-ms-flex-direction:row;flex-direction:row;padding:56px 120px;}}/*!sc*/
# data-styled.g305[id="hero-cardstyle__HeaderCardInner-sc-8gb5fx-1"]{content:"GiGZF,"}/*!sc*/
# .kjXGTC{position:relative;width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;}/*!sc*/
# .kjXGTC picture,.kjXGTC .heroOverlayImage{display:none;}/*!sc*/
# @media screen and (min-width:768px){.kjXGTC{-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-basis:50%;-ms-flex-preferred-size:50%;flex-basis:50%;padding:0 8px 8px 0;}.kjXGTC picture,.kjXGTC .heroOverlayImage{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;height:100%;}.kjXGTC .heroOverlayImage{position:relative;width:100%;z-index:2;-webkit-filter:grayscale(100%);filter:grayscale(100%);border-radius:0 40px 40px 40px;}.kjXGTC picture::after{position:absolute;z-index:1;content:'';top:8px;right:0;left:8px;bottom:0;background-color:#00b6b4;border-radius:0 40px 48px 40px;}}/*!sc*/
# @media screen and (min-width:1024px){.kjXGTC{-webkit-flex-basis:60%;-ms-flex-preferred-size:60%;flex-basis:60%;}}/*!sc*/
# @media screen and (min-width:1440px){.kjXGTC{-webkit-flex-basis:50%;-ms-flex-preferred-size:50%;flex-basis:50%;}}/*!sc*/
# data-styled.g306[id="hero-cardstyle__HeaderCardImage-sc-8gb5fx-2"]{content:"kjXGTC,"}/*!sc*/
# .cEGHQd{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex-basis:100%;-ms-flex-preferred-size:100%;flex-basis:100%;width:100%;font-family:Proxima Nova;font-weight:400;font-size:16px;color:#212121;line-height:24px;}/*!sc*/
# @media screen and (min-width:768px){.cEGHQd{-webkit-flex-basis:50%;-ms-flex-preferred-size:50%;flex-basis:50%;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:flex-end;-webkit-box-align:flex-end;-ms-flex-align:flex-end;align-items:flex-end;}}/*!sc*/
# @media screen and (min-width:1024px){.cEGHQd{-webkit-flex-basis:40%;-ms-flex-preferred-size:40%;flex-basis:40%;}}/*!sc*/
# @media screen and (min-width:1440px){.cEGHQd{-webkit-flex-basis:50%;-ms-flex-preferred-size:50%;flex-basis:50%;}}/*!sc*/
# data-styled.g307[id="hero-cardstyle__HeaderCardContent-sc-8gb5fx-3"]{content:"cEGHQd,"}/*!sc*/
# .fatNLb{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;width:100%;}/*!sc*/
# @media screen and (min-width:768px){.fatNLb{box-sizing:border-box;padding-left:32px;}}/*!sc*/
# @media screen and (min-width:1440px){.fatNLb{padding-left:100px;}}/*!sc*/
# data-styled.g308[id="hero-cardstyle__HeaderCardContentInner-sc-8gb5fx-4"]{content:"fatNLb,"}/*!sc*/
# .kqyGDd{font-family:Proxima Nova;font-weight:700;font-size:16px;color:#212121;line-height:20px;font-family:'Proxima Nova SemiBold',Helvetica,Arial,Sans-Serif;color:#ffffff;margin:0 0 32px 0;text-align:center;}/*!sc*/
# @media screen and (min-width:768px){.kqyGDd{font-family:Proxima Nova;font-weight:700;font-size:21px;color:#212121;line-height:26px;font-family:'Proxima Nova SemiBold',Helvetica,Arial,Sans-Serif;color:#ffffff;margin:0 0 24px 0;text-align:inherit;}}/*!sc*/
# @media screen and (min-width:1024px){.kqyGDd{width:70%;}}/*!sc*/
# data-styled.g309[id="hero-cardstyle__HeaderCardTitle-sc-8gb5fx-5"]{content:"kqyGDd,"}/*!sc*/
# .fiJmTK{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;}/*!sc*/
# data-styled.g310[id="hero-cardstyle__HeaderCardLinkWrap-sc-8gb5fx-6"]{content:"fiJmTK,"}/*!sc*/
# .idLVDw{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;background-color:#402965;border:2px solid #6e46ae;border-radius:8px;padding:12px 24px;max-height:68px;}/*!sc*/
# .idLVDw:not(:last-of-type){margin-bottom:12px;}/*!sc*/
# .idLVDw,.idLVDw a{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .idLVDw,.idLVDw a,.idLVDw:visited,.idLVDw a:visited{color:#ffffff;}/*!sc*/
# .idLVDw:hover,.idLVDw:focus,.idLVDw:active{background-color:#57378a;}/*!sc*/
# data-styled.g311[id="hero-cardstyle__HeaderCardLink-sc-8gb5fx-7"]{content:"idLVDw,"}/*!sc*/
# .QzVJY{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;height:40px;width:40px;}/*!sc*/
# data-styled.g312[id="hero-cardstyle__HeaderCardIconWrap-sc-8gb5fx-8"]{content:"QzVJY,"}/*!sc*/
# @-webkit-keyframes kvdmkM{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);background-color:#e9e7f7;}33.33%{-webkit-transform:scale(calc(16 / 12));-ms-transform:scale(calc(16 / 12));transform:scale(calc(16 / 12));background-color:#6e46ae;}66.66%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);background-color:#e9e7f7;}}/*!sc*/
# @keyframes kvdmkM{0%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);background-color:#e9e7f7;}33.33%{-webkit-transform:scale(calc(16 / 12));-ms-transform:scale(calc(16 / 12));transform:scale(calc(16 / 12));background-color:#6e46ae;}66.66%{-webkit-transform:scale(1);-ms-transform:scale(1);transform:scale(1);background-color:#e9e7f7;}}/*!sc*/
# data-styled.g351[id="sc-keyframes-kvdmkM"]{content:"kvdmkM,"}/*!sc*/
# </style><link as="script" href="/50-cc0d4fc7be441ac72a9e.js" rel="prefetch"/><link as="script" href="/49-574775eac29453aab28a.js" rel="prefetch"/><link as="script" href="/33-9ff80d0ede7b7395cfb4.js" rel="prefetch"/><link as="script" href="/32-0d9d43051297a8d92e20.js" rel="prefetch"/><link as="script" href="/31-4ac6e895c9394888e307.js" rel="prefetch"/><link as="script" href="/30-dca1d03d1edc67065e81.js" rel="prefetch"/><link as="script" href="/29-e519832f31284dfdc063.js" rel="prefetch"/><link as="script" href="/48-7e3285ed306f469de989.js" rel="prefetch"/><link as="script" href="/webpack-runtime-326dcc4547fb95fd4ec9.js" rel="preload"/><link as="script" href="/framework-3cdc6cdb8452eba5b733.js" rel="preload"/><link as="script" href="/dc6a8720040df98778fe970bf6c000a41750d3ae-d2b062451707b58f4b36.js" rel="preload"/><link as="script" href="/app-ef81666cd1892d05ba64.js" rel="preload"/><link as="script" href="/5e8164b9-3ee6734b6e4b4a7e0426.js" rel="preload"/><link as="script" href="/df3a4cf5-4dc66fbee61d477cdb99.js" rel="preload"/><link as="script" href="/ae8bed67-441ff9c387ca44103d79.js" rel="preload"/><link as="script" href="/c9f6e52ccf71b2b23157f6e1ea1b4266bfba9553-e8a00dd482a6be63e5e0.js" rel="preload"/><link as="script" href="/ba46a51dc845a843d9bfb327dc2254d9ee8ff9a3-58d2748d03597b4bd745.js" rel="preload"/><link as="script" href="/36ac01238f33c59ef4bf5e573dc09d41bc1feb4f-5f28c57d0b2f8a203fdc.js" rel="preload"/><link as="script" href="/component---src-pages-index-tsx-40f169c91279cc582dc6.js" rel="preload"/><link as="fetch" crossorigin="anonymous" href="/page-data/index/page-data.json" rel="preload"/><link as="fetch" crossorigin="anonymous" href="/page-data/app-data.json" rel="preload"/></head><body><div id="___gatsby"><div id="gatsby-focus-wrapper" style="outline:none" tabindex="-1"><style>@font-face {
#     font-family: &#x27;Proxima Nova&#x27;;
#     src: url(&#x27;/static/Proxima-Nova-Regular-2000f9d8a8df2554f0c0994f44057524.woff2&#x27;);
#     font-display: swap;
#   }<!-- -->@font-face {
#     font-family: &#x27;Proxima Nova Bold&#x27;;
#     src: url(&#x27;/static/Proxima-Nova-Bold-d31288e9360bd8c887f67632bd998983.woff2&#x27;);
#     font-display: swap;
#   }<!-- -->@font-face {
#     font-family: &#x27;Proxima Nova SemiBold&#x27;;
#     src: url(&#x27;/static/Proxima-Nova-SemiBold-2b6fce92d9bb4f455f961b9c9df136b9.woff2&#x27;);
#     font-display: swap;
#   }</style><div class="sc-jvvksu QOCLR ds-header" data-ds-version="3.0.0"><div class="sc-gnnDb jlFVjm"></div><div id="modal-root"></div><header class="sc-edERGn iozbWu"><div class="sc-jlsrNB gXtbrX"><div class="sc-hkgtus hEWBGm"><div class="sc-dcgwPl bYBkMg"></div></div><div class="sc-iWBNLc kOTfSo"><a aria-label="Monster" href="https://www.monster.com" title="Monster"><div class="sc-hkgtus hEWBGm"><svg aria-label="Monster" class="sc-hJZKUC fbeWUH" height="100%" role="img" viewbox="0 0 48 48" width="48px" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><title>Monster</title><g fill="none" fill-rule="evenodd"><circle cx="24" cy="24" fill="#6e46ae" r="24"></circle><path d="M34 14L24.001 23.355 14 14 14 34 18.516 34 18.516 24.323 24 29.161 29.484 24.323 29.484 34 34 34z" fill="#FFF"></path></g></svg></div><div class="sc-bSqaIl dnxMQg"><svg aria-label="Monster" class="sc-hYQoXb hqcOzp" height="24px" role="img" viewbox="0 0 144 24" width="144px" xmlns="http://www.w3.org/2000/svg"><g fill="none" fill-rule="evenodd"><path d="M68.249 23.807l-11.647-9.645v9.38h-4.63V4.347l11.647 9.645v-9.38h4.63v19.194M98.943 23.542H94.16V9.018h-4.356V4.613h13.495v4.405h-4.356v14.524M120.241 23.542h-11.987V4.612h11.864v4.406h-7.156v2.86h5.72v4.3h-5.72v2.958h7.28v4.406M136.45 14.29c1.018-.375 4.474-1.91 4.474-6.29 0-3.167-2.502-6.717-7.905-6.717h-6.996v22.258h4.818V14.75h.246l6.905 8.791h5.758l-7.3-9.25zm-2.72-3.855h-2.89V5.761h2.89c1.528 0 2.533 1.025 2.533 2.337 0 1.146-.849 2.337-2.533 2.337zM21.91.18L11.082 11.04.251.18V23.54H5.07v-11.76l6.01 6.032 6.012-6.032v11.76h4.819V.18M79.71 23.82c-4.328 0-6.577-2.426-6.953-2.794l2.43-3.446c.38.336 2.103 1.86 4.376 1.86 1.543 0 1.99-.739 1.99-1.33 0-.615-.46-1.16-2.09-1.768l-1.434-.535c-2.643-.986-4.325-2.83-4.325-5.568 0-3.358 2.69-5.908 6.51-5.908 3.443 0 5.372 1.655 5.585 1.842l-2.276 3.549c-.466-.32-1.752-1.02-3.176-1.02-1.332 0-1.94.568-1.94 1.25 0 .888.79 1.265 2.194 1.789l1.299.484c2.72 1.014 4.43 3.097 4.43 5.59 0 3.422-2.704 6.005-6.62 6.005" fill="#6E46AE"></path><path d="M36.94 4.334c-5.5 0-9.84 4.362-9.84 9.743s4.34 9.744 9.84 9.744c5.501 0 9.841-4.363 9.841-9.744 0-5.38-4.34-9.743-9.84-9.743m0 14.925c-2.9 0-5.13-2.32-5.13-5.182 0-2.862 2.23-5.182 5.13-5.182 2.899 0 5.13 2.32 5.13 5.182 0 2.862-2.231 5.182-5.13 5.182" fill="#00B6B4"></path></g></svg></div></a></div><div class="sc-bSqaIl dnxMQg"></div><div class="sc-bSqaIl dnxMQg"><div class="sc-itWPBs ckCBlB"><a aria-label="Profile" class="sc-JEhMO lamlMS" href="https://www.monster.com/profile/detail" title="Profile"><svg aria-hidden="true" class="MuiSvgIcon-root" focusable="false" viewbox="0 0 24 24"><path d="M12 2C6.48 2 2 6.48 2 12s4.48 10 10 10 10-4.48 10-10S17.52 2 12 2zM7.07 18.28c.43-.9 3.05-1.78 4.93-1.78s4.51.88 4.93 1.78C15.57 19.36 13.86 20 12 20s-3.57-.64-4.93-1.72zm11.29-1.45c-1.43-1.74-4.9-2.33-6.36-2.33s-4.93.59-6.36 2.33C4.62 15.49 4 13.82 4 12c0-4.41 3.59-8 8-8s8 3.59 8 8c0 1.82-.62 3.49-1.64 4.83zM12 6c-1.94 0-3.5 1.56-3.5 3.5S10.06 13 12 13s3.5-1.56 3.5-3.5S13.94 6 12 6zm0 5c-.83 0-1.5-.67-1.5-1.5S11.17 8 12 8s1.5.67 1.5 1.5S12.83 11 12 11z"></path></svg></a></div></div><div class="sc-hkgtus hEWBGm"><div class="sc-cjrPHo lhfTMq"><button aria-expanded="false" aria-haspopup="true" aria-label="Open Menu" class="sc-bGaVxB ivlKqd"><span class="MuiBadge-root sc-igXgud FXfhh"><div class="sc-fydGpi iMiare"></div><span class="MuiBadge-badge MuiBadge-anchorOriginTopLeftCircular MuiBadge-invisible MuiBadge-dot"></span></span></button></div></div></div><nav aria-label="Main Menu" class="sc-kHxTfl kbXrNq"><div class="sc-lhMiDA hXhzHY"><div class="sc-hkgtus hEWBGm"><ul class="sc-cvlWTT hTrxPC" role="menu"><li class="sc-fTQvRK hwgDXS" role="menuitem"><a aria-label="Find Jobs" data-name="header_label_0" href="https://www.monster.com">Find Jobs</a></li><li class="sc-fTQvRK hwgDXS" role="menuitem"><a aria-label="Salary Tools" data-name="header_label_1" href="https://www.monster.com/salary/">Salary Tools</a></li><li c ...
